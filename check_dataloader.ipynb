# %% [markdown]
# Let's visualize a batch using our Dataset and Dataloaders.

# %%
from dataset import create_dataloaders, show_image_grid

# %%
data_file = 'mnist_data.h5'
train_loader, val_loader, test_loader = create_dataloaders(data_file)

# %%
inputs, labels = next(iter(train_loader))
show_image_grid(inputs, labels)
